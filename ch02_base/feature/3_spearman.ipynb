# %%
import pandas as pd

# %%
# 定义数据
X = [[5], [8], [10], [12], [15], [3], [7], [9], [14], [6]]
y = [55, 65, 70, 75, 85, 50, 60, 82, 70, 58]

X = pd.DataFrame(X)
y = pd.Series(y)

# %%
# 计算斯皮尔曼相关系数
sc = X.corrwith(y, method='spearman')
print(sc)
# Out:
# 0    0.905779
# dtype: float64
